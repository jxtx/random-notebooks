# %%
from __future__ import division

import math
import pandas
import random
import numpy

from matplotlib import pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
a = numpy.random.poisson( 1000, (100,10))

# %%
sns.set_style("ticks")
cg = sns.clustermap( a, col_cluster=False, cmap="plasma" )
plt.setp(cg.ax_heatmap.yaxis.get_majorticklabels(), rotation=0)
cg
